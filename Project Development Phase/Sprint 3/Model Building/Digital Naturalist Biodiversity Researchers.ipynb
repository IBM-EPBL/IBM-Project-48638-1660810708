jpg
#   inflating: datasetbd/train/plants/zinnia_flower_red/zinnia_flower_red_94.jpg
#   inflating: datasetbd/train/plants/zinnia_flower_red/zinnia_flower_red_95.jpg
#   inflating: datasetbd/train/plants/zinnia_flower_red/zinnia_flower_red_96.jpg
#   inflating: datasetbd/train/plants/zinnia_flower_red/zinnia_flower_red_97.jpg
#   inflating: datasetbd/train/plants/zinnia_flower_red/zinnia_flower_red_98.jpg
#   inflating: datasetbd/train/plants/zinnia_flower_red/zinnia_flower_red_99.jpg

# %% [markdown]
# ## **Image Preprocessing**

# %% [markdown]
# **1.Import The ImageDataGenerator Library**

# %%
#import required lib
import numpy as np
import tensorflow as tf
import keras
import keras.backend as K
from keras.optimizers import SGD, Adam, Adagrad, RMSprop
from keras.applications import *
from keras.preprocessing import *
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.models import Sequential
from keras.layers import Dense, Conv2D, MaxPool2D, Flatten, Activation, BatchNormalization, Dropout
from keras.utils.np_utils import to_categorical
from sklearn.model_selection import train_test_split 
import matplotlib.pyplot as plt
import glob
from PIL import Image
import os
from os import listdir

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# **2.Configure ImageDataGenerator Class**

# %%
#Creating augmentation on training variable
train_datagen = ImageDataGenerator(rescale=1./255,
                                   shear_range = 0.1,
                                   zoom_range=0.1,
                                   horizontal_flip=True)

# %%
# Creating augmentation on testing variable

test_datagen = ImageDataGenerator(rescale=1./255)

# %% [markdown]
# **3.Apply ImageDataGenerator Functionality To Trainset And Testset**

# %%
# Passing training data to train variable for animals

xtrain = train_datagen.flow_from_directory('/content/datasetbd/train/animals',
                                           target_size=(224,224),
                                           class_mode='categorical',
                                           batch_size=10)
# Out:
# Found 1154 images belonging to 20 classes.

# %%
# Passing testing data to test variable for animals

xtest = test_datagen.flow_from_directory('/content/datasetbd/test/animals',
                                           target_size=(224,224),
                                           class_mode='categorical',
                                           batch_size=10)
# Out:
# Found 1154 images belonging to 20 classes.

# %%
# Passing training data to train variable for birds

xtrain1 = train_datagen.flow_from_directory('/content/datasetbd/train/birds',
                                           target_size=(224,224),
                                           class_mode='categorical',
                                           batch_size=10)
# Out:
# Found 3496 images belonging to 22 classes.

# %%
# Passing testing data to test variable for birds

xtest1 = test_datagen.flow_from_directory('/content/datasetbd/test/birds',
                                           target_size=(224,224),
                                           class_mode='categorical',
                                           batch_size=10)
# Out:
# Found 3496 images belonging to 22 classes.

# %%
# Passing training data to train variable for flowers

xtrain2 = train_datagen.flow_from_directory('/content/datasetbd/train/flowers',
                                           target_size=(224,224),
                                           class_mode='categorical',
                                           batch_size=10)
# Out:
# Found 4317 images belonging to 5 classes.

# %%
# Passing testing data to test variable for flowers

xtest2 = test_datagen.flow_from_directory('/content/datasetbd/test/flowers',
                                           target_size=(224,224),
                                           class_mode='categorical',
                                           batch_size=10)
# Out:
# Found 4317 images belonging to 5 classes.

# %%
# Passing training data to train variable for marine animals

xtrain3 = train_datagen.flow_from_directory('/content/datasetbd/train/marine animals',
                                           target_size=(224,224),
                                           class_mode='categorical',
                                           batch_size=10)
# Out:
# Found 11742 images belonging to 19 classes.

# %%
# Passing testing data to test variable for marine animals

xtest3 = test_datagen.flow_from_directory('/content/datasetbd/test/marine animals',
                                           target_size=(224,224),
                                           class_mode='categorical',
                                           batch_size=10)
# Out:
# Found 11742 images belonging to 19 classes.

# %%
# Passing training data to train variable for plants

xtrain4 = train_datagen.flow_from_directory('/content/datasetbd/train/plants',
                                           target_size=(224,224),
                                           class_mode='categorical',
                                           batch_size=10)
# Out:
# Found 3688 images belonging to 27 classes.

# %%
# Passing testing data to test variable for plants

xtest4 = test_datagen.flow_from_directory('/content/datasetbd/test/plants',
                                           target_size=(224,224),
                                           class_mode='categorical',
                                           batch_size=10)
# Out:
# Found 3688 images belonging to 27 classes.

# %% [markdown]
# # **For Animals**

# %% [markdown]
# **1.Importing The Model Building Libraries**

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Lambda, Dense, Flatten
from tensorflow.keras.models import Model
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.applications.vgg19 import VGG19
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator,load_img
from tensorflow.keras.models import Sequential
import numpy as np
from glob import glob

# %% [markdown]
# **2.Loading The Model**

# %%
IMAGE_SIZE = [224, 224]

train_path = '/content/datasetbd/train/animals'
valid_path = '/content/datasetbd/test/animals'

# %%
vgg16 = VGG16(input_shape=IMAGE_SIZE + [3], weights='imagenet', include_top=False)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 3s 0us/step

# %% [markdown]
# **3.Adding Flatten Layer**

# %%
for layer in vgg16.layers:
    layer.trainable = False

# %%
folders = glob('/content/datasetbd/train/animals/*')

# %%
folders
# Out:
# ['/content/datasetbd/train/animals/duck',
#  '/content/datasetbd/train/animals/gatto',
#  '/content/datasetbd/train/animals/fly',
#  '/content/datasetbd/train/animals/dolphin',
#  '/content/datasetbd/train/animals/bee',
#  '/content/datasetbd/train/animals/dragonfly',
#  '/content/datasetbd/train/animals/hornbill',
#  '/content/datasetbd/train/animals/hippopotamus',
#  '/content/datasetbd/train/animals/horse',
#  '/content/datasetbd/train/animals/badger',
#  '/content/datasetbd/train/animals/eagle',
#  '/content/datasetbd/train/animals/fox',
#  '/content/datasetbd/train/animals/flamingo',
#  '/content/datasetbd/train/animals/gallina',
#  '/content/datasetbd/train/animals/bat',
#  '/content/datasetbd/train/animals/hummingbird',
#  '/content/datasetbd/train/animals/elephant',
#  '/content/datasetbd/train/animals/donkey',
#  '/content/datasetbd/train/animals/hedgehog',
#  '/content/datasetbd/train/animals/bear']

# %%
x = Flatten()(vgg16.output)

# %%
len(folders)
# Out:
# 20

# %% [markdown]
# **4. Adding Output Layer**

# %%
prediction = Dense(len(folders), activation='softmax')(x)

# %% [markdown]
# **5. Creating A Model Object**

# %%
model = Model(inputs=vgg16.input, outputs=prediction)

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten (Flatten)           (None, 25088)             0
#
#  dense (Dense)               (None, 20)                501780
#
# =================================================================
# Total params: 15,216,468
# Trainable params: 501,780
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %% [markdown]
# **6. Configure The Learning Process**

# %%
model.compile(
  loss='categorical_crossentropy',
  optimizer='adam',
  metrics=['accuracy']
)

# %% [markdown]
# **7. Train The Model**

# %%
r = model.fit(
  xtrain,
  validation_data=xtest,
  epochs=10,
  steps_per_epoch=len(xtrain),
  validation_steps=len(xtest)
)
# Out:
# Epoch 1/10
# 116/116 [==============================] - 52s 366ms/step - loss: 2.2330 - accuracy: 0.4350 - val_loss: 0.5964 - val_accuracy: 0.8310
# Epoch 2/10
# 116/116 [==============================] - 42s 360ms/step - loss: 0.6239 - accuracy: 0.8120 - val_loss: 0.1985 - val_accuracy: 0.9437
# Epoch 3/10
# 116/116 [==============================] - 42s 359ms/step - loss: 0.3197 - accuracy: 0.9125 - val_loss: 0.2264 - val_accuracy: 0.9376
# Epoch 4/10
# 116/116 [==============================] - 41s 357ms/step - loss: 0.1878 - accuracy: 0.9428 - val_loss: 0.0718 - val_accuracy: 0.9818
# Epoch 5/10
# 116/116 [==============================] - 42s 363ms/step - loss: 0.0712 - accuracy: 0.9835 - val_loss: 0.0444 - val_accuracy: 0.9887
# Epoch 6/10
# 116/116 [==============================] - 42s 365ms/step - loss: 0.0565 - accuracy: 0.9853 - val_loss: 0.0541 - val_accuracy: 0.9844
# Epoch 7/10
# 116/116 [==============================] - 42s 359ms/step - loss: 0.0336 - accuracy: 0.9939 - val_loss: 0.0187 - val_accuracy: 0.9974
# Epoch 8/10
# 116/116 [==============================] - 42s 360ms/step - loss: 0.0449 - accuracy: 0.9853 - val_loss: 0.0164 - val_accuracy: 0.9957
# Epoch 9/10
# 116/116 [==============================] - 42s 362ms/step - loss: 0.0388 - accuracy: 0.9861 - val_loss: 0.0035 - val_accuracy: 1.0000
# Epoch 10/10
# 116/116 [==============================] - 42s 362ms/step - loss: 0.0155 - accuracy: 0.9948 - val_loss: 0.0040 - val_accuracy: 1.0000

# %% [markdown]
# **8. Save The Model**

# %%
from tensorflow.keras.models import load_model

model.save('/content/datasetbd/Model/animals.h5')

# %% [markdown]
# **9. Test The Model**

# %%
from tensorflow.keras.models import load_model
import cv2
from skimage.transform import resize

# %%
model = load_model('/content/datasetbd/Model/animals.h5')

# %%
def detect(frame):
  img = cv2.resize(frame,(224,224))
  img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

  if(np.max(img)>1):
    img = img/255.0
  img = np.array([img])
  prediction = model.predict(img)
  label = ["badger","bat","bear","bee","dolphin","donkey","dragonfly","duck","eagle","elephant","flamingo","fly","fox","gallina","gatto","hedgehog","hippopotamus","hornbill","horse","hummingbird"]
  preds = label[np.argmax(prediction)]
  return preds

# %%
import numpy as np

# %%
data = "/content/datasetbd/train/animals/bear/048d7b29e3.jpg"
image = cv2.imread(data)
print(detect(image))
# Out:
# 1/1 [==============================] - 1s 812ms/step
# bear

# %% [markdown]
# # **FOR Birds**

# %% [markdown]
# # **MODEL BUILDING**

# %% [markdown]
# **1. Importing The Model Building Libraries**

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Lambda, Dense, Flatten
from tensorflow.keras.models import Model
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.applications.vgg19 import VGG19
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator,load_img
from tensorflow.keras.models import Sequential
import numpy as np
from glob import glob

# %% [markdown]
# **2. Loading The Model**

# %%
IMAGE_SIZE = [224, 224]

train_path = '/content/datasetbd/train/birds'
valid_path = '/content/datasetbd/test/birds'

# %%
vgg16 = VGG16(input_shape=IMAGE_SIZE + [3], weights='imagenet', include_top=False)

# %% [markdown]
# **3. Adding Flatten Layer**

# %%
for layer in vgg16.layers:
    layer.trainable = False

# %%
folders = glob('/content/datasetbd/train/birds/*')

# %%
folders
# Out:
# ['/content/datasetbd/train/birds/CAMPO FLICKER',
#  '/content/datasetbd/train/birds/SKUA',
#  '/content/datasetbd/train/birds/BALTIMORE ORIOLE',
#  '/content/datasetbd/train/birds/SMITHS LONGSPUR',
#  '/content/datasetbd/train/birds/BANANAQUIT',
#  '/content/datasetbd/train/birds/BAND TAILED GUAN',
#  '/content/datasetbd/train/birds/PEACOCK',
#  '/content/datasetbd/train/birds/PARUS MAJOR',
#  '/content/datasetbd/train/birds/PEREGRINE FALCON',
#  '/content/datasetbd/train/birds/RED HONEY CREEPER',
#  '/content/datasetbd/train/birds/CALIFORNIA QUAIL',
#  '/content/datasetbd/train/birds/ABBOTTS BABBLER',
#  '/content/datasetbd/train/birds/YELLOW HEADED BLACKBIRD',
#  '/content/datasetbd/train/birds/BLACKBURNIAM WARBLER',
#  '/content/datasetbd/train/birds/CANARY',
#  '/content/datasetbd/train/birds/PATAGONIAN SIERRA FINCH',
#  '/content/datasetbd/train/birds/ABBOTTS BOOBY',
#  '/content/datasetbd/train/birds/PHILIPPINE EAGLE',
#  '/content/datasetbd/train/birds/SHORT BILLED DOWITCHER',
#  '/content/datasetbd/train/birds/WHITE THROATED BEE EATER',
#  '/content/datasetbd/train/birds/WILD TURKEY',
#  '/content/datasetbd/train/birds/CALIFORNIA GULL']

# %%
x = Flatten()(vgg16.output)

# %%
len(folders)
# Out:
# 22

# %% [markdown]
# **4. Adding Output Layer**

# %%
prediction = Dense(len(folders), activation='softmax')(x)

# %% [markdown]
# **5. Creating A Model Object**

# %%
model = Model(inputs=vgg16.input, outputs=prediction)

# %%
model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten_1 (Flatten)         (None, 25088)             0
#
#  dense_1 (Dense)             (None, 22)                551958
#
# =================================================================
# Total params: 15,266,646
# Trainable params: 551,958
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %% [markdown]
# **6. Configure The Learning Process**

# %%
model.compile(
  loss='categorical_crossentropy',
  optimizer='adam',
  metrics=['accuracy']
)

# %% [markdown]
# **7. Train The Model**

# %%
r = model.fit(
  xtrain1,
  validation_data=xtest1,
  epochs=10,
  steps_per_epoch=len(xtrain1),
  validation_steps=len(xtest1)
)
# Out:
# Epoch 1/10
# 350/350 [==============================] - 69s 194ms/step - loss: 1.5646 - accuracy: 0.6290 - val_loss: 0.4805 - val_accuracy: 0.8584
# Epoch 2/10
# 350/350 [==============================] - 65s 186ms/step - loss: 0.6048 - accuracy: 0.8384 - val_loss: 0.5603 - val_accuracy: 0.8533
# Epoch 3/10
# 350/350 [==============================] - 67s 191ms/step - loss: 0.4287 - accuracy: 0.8790 - val_loss: 0.1448 - val_accuracy: 0.9551
# Epoch 4/10
# 350/350 [==============================] - 65s 185ms/step - loss: 0.2724 - accuracy: 0.9236 - val_loss: 0.1948 - val_accuracy: 0.9471
# Epoch 5/10
# 350/350 [==============================] - 66s 190ms/step - loss: 0.2210 - accuracy: 0.9399 - val_loss: 0.1191 - val_accuracy: 0.9645
# Epoch 6/10
# 350/350 [==============================] - 65s 184ms/step - loss: 0.2634 - accuracy: 0.9291 - val_loss: 0.2201 - val_accuracy: 0.9408
# Epoch 7/10
# 350/350 [==============================] - 65s 184ms/step - loss: 0.1662 - accuracy: 0.9528 - val_loss: 0.2111 - val_accuracy: 0.9396
# Epoch 8/10
# 350/350 [==============================] - 65s 186ms/step - loss: 0.2214 - accuracy: 0.9465 - val_loss: 0.1339 - val_accuracy: 0.9600
# Epoch 9/10
# 350/350 [==============================] - 65s 185ms/step - loss: 0.1444 - accuracy: 0.9605 - val_loss: 0.1544 - val_accuracy: 0.9605
# Epoch 10/10
# 350/350 [==============================] - 65s 186ms/step - loss: 0.1237 - accuracy: 0.9642 - val_loss: 0.4835 - val_accuracy: 0.9196

# %%
from tensorflow.keras.models import load_model

model.save('/content/datasetbd/Model/birds.h5')

# %%
from tensorflow.keras.models import load_model
import cv2
from skimage.transform import resize

# %%
model = load_model('/content/datasetbd/Model/birds.h5')

# %%
def detect(frame):
  img = cv2.resize(frame,(224,224))
  img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
  
  if(np.max(img)>1):
    img = img/255.0
  img = np.array([img])
  prediction = model.predict(img)
  label = ["ABBOTTS BABBLER","ABBOTTS BOOBY","BALTIMORE ORIOLE","BANANAOUIT","BAND TAILED GUAN","BLACKBURNIAM WARBLER","CALIFORNIA GULL","CALIFORNIA QUAIL","CAMPO FLICKER","CANARY","PARUS MAJOR","PATAGONIAN SIERRA FINCH","PEACOCK","PEREGRINE FALCON","PHILIPPINE EAGLE","RED HONEY CREEPER","SHORT BILLED DOWITCHER","SKUA","SMITHS LONGSPUR","WHITE THROATED BEE EATER","WILD TURKEY","YELLOW HEADED BLACKBIRD"]
  preds = label[np.argmax(prediction)]
  return preds

# %%
import numpy as np

# %%
data = "/content/datasetbd/train/birds/SKUA/012.jpg"
image = cv2.imread(data)
print(detect(image))
# Out:
# 1/1 [==============================] - 0s 119ms/step
# SKUA

# %% [markdown]
# # **For Flowers**

# %% [markdown]
# # **MODEL BUILDING**

# %% [markdown]
# **1. Importing The Model Building Libraries**

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Lambda, Dense, Flatten
from tensorflow.keras.models import Model
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.applications.vgg19 import VGG19
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator,load_img
from tensorflow.keras.models import Sequential
import numpy as np
from glob import glob

# %% [markdown]
# **2. Loading The Model**

# %%
IMAGE_SIZE = [224, 224]

train_path = '/content/datasetbd/train/flowers'
valid_path = '/content/datasetbd/test/flowers'

# %% [markdown]
# **3. Adding Flatten Layer**

# %%
vgg16 = VGG16(input_shape=IMAGE_SIZE + [3], weights='imagenet', include_top=False)

# %%
for layer in vgg16.layers:
    layer.trainable = False

# %%
folders = glob('/content/datasetbd/train/flowers/*')

# %%
folders
# Out:
# ['/content/datasetbd/train/flowers/daisy',
#  '/content/datasetbd/train/flowers/rose',
#  '/content/datasetbd/train/flowers/sunflower',
#  '/content/datasetbd/train/flowers/tulip',
#  '/content/datasetbd/train/flowers/dandelion']

# %%
x = Flatten()(vgg16.output)

# %%
len(folders)
# Out:
# 5

# %% [markdown]
# **4. Adding Output Layer**

# %%
prediction = Dense(len(folders), activation='softmax')(x)

# %% [markdown]
# **5. Creating A Model Object**

# %%
model = Model(inputs=vgg16.input, outputs=prediction)

# %%
model.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten_2 (Flatten)         (None, 25088)             0
#
#  dense_2 (Dense)             (None, 5)                 125445
#
# =================================================================
# Total params: 14,840,133
# Trainable params: 125,445
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %% [markdown]
# **6. Configure The Learning Process**

# %%
model.compile(
  loss='categorical_crossentropy',
  optimizer='adam',
  metrics=['accuracy']
)

# %% [markdown]
# **7. Train The Model**

# %%
r = model.fit(
  xtrain2,
  validation_data=xtest2,
  epochs=10,
  steps_per_epoch=len(xtrain2),
  validation_steps=len(xtest2)
)
# Out:
# Epoch 1/10
# 432/432 [==============================] - 88s 202ms/step - loss: 0.9286 - accuracy: 0.7074 - val_loss: 0.4834 - val_accuracy: 0.8314
# Epoch 2/10
# 432/432 [==============================] - 86s 198ms/step - loss: 0.6037 - accuracy: 0.8128 - val_loss: 0.3259 - val_accuracy: 0.8927
# Epoch 3/10
# 432/432 [==============================] - 86s 199ms/step - loss: 0.4161 - accuracy: 0.8650 - val_loss: 0.3284 - val_accuracy: 0.8883
# Epoch 4/10
# 432/432 [==============================] - 86s 200ms/step - loss: 0.3591 - accuracy: 0.8877 - val_loss: 0.2088 - val_accuracy: 0.9291
# Epoch 5/10
# 432/432 [==============================] - 86s 199ms/step - loss: 0.2776 - accuracy: 0.9097 - val_loss: 0.1752 - val_accuracy: 0.9377
# Epoch 6/10
# 432/432 [==============================] - 88s 203ms/step - loss: 0.2468 - accuracy: 0.9155 - val_loss: 0.1139 - val_accuracy: 0.9599
# Epoch 7/10
# 432/432 [==============================] - 86s 199ms/step - loss: 0.2309 - accuracy: 0.9233 - val_loss: 0.1249 - val_accuracy: 0.9565
# Epoch 8/10
# 432/432 [==============================] - 86s 198ms/step - loss: 0.1968 - accuracy: 0.9331 - val_loss: 0.3604 - val_accuracy: 0.9034
# Epoch 9/10
# 432/432 [==============================] - 85s 196ms/step - loss: 0.1940 - accuracy: 0.9386 - val_loss: 0.1323 - val_accuracy: 0.9544
# Epoch 10/10
# 432/432 [==============================] - 86s 199ms/step - loss: 0.1886 - accuracy: 0.9393 - val_loss: 0.1470 - val_accuracy: 0.9453

# %%
from tensorflow.keras.models import load_model

model.save('/content/datasetbd/Model/flowers.h5')

# %%
from tensorflow.keras.models import load_model
import cv2
from skimage.transform import resize

# %%
model = load_model('/content/datasetbd/Model/flowers.h5')

# %%
def detect(frame):
  img = cv2.resize(frame,(224,224))
  img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
  
  if(np.max(img)>1):
    img = img/255.0
  img = np.array([img])
  prediction = model.predict(img)
  label = ["daisy","dandelion","rose","sunflower","tulip"]
  preds = label[np.argmax(prediction)]
  return preds

# %%
import numpy as np

# %%
data = "/content/datasetbd/train/flowers/rose/10503217854_e66a804309.jpg"
image = cv2.imread(data)
print(detect(image))
# Out:
# 1/1 [==============================] - 0s 128ms/step
# rose

# %% [markdown]
# # **For Marine Animals**

# %% [markdown]
# # **MODEL BUILDING**

# %% [markdown]
# **1. Importing The Model Building Libraries**

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Lambda, Dense, Flatten
from tensorflow.keras.models import Model
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.applications.vgg19 import VGG19
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator,load_img
from tensorflow.keras.models import Sequential
import numpy as np
from glob import glob

# %% [markdown]
# **2. Loading The Model**

# %%
IMAGE_SIZE = [224, 224]

train_path = '/content/datasetbd/train/marine animals'
valid_path = '/content/datasetbd/test/marine animals'

# %%
vgg16 = VGG16(input_shape=IMAGE_SIZE + [3], weights='imagenet', include_top=False)

# %% [markdown]
# **3. Adding Flatten Layer**

# %%
for layer in vgg16.layers:
    layer.trainable = False

# %%
folders = glob('/content/datasetbd/train/marine animals/*')

# %%
folders
# Out:
# ['/content/datasetbd/train/marine animals/Puffers',
#  '/content/datasetbd/train/marine animals/Sharks',
#  '/content/datasetbd/train/marine animals/Nudibranchs',
#  '/content/datasetbd/train/marine animals/Octopus',
#  '/content/datasetbd/train/marine animals/Squid',
#  '/content/datasetbd/train/marine animals/Seahorse',
#  '/content/datasetbd/train/marine animals/Eel',
#  '/content/datasetbd/train/marine animals/Lobster',
#  '/content/datasetbd/train/marine animals/Seal',
#  '/content/datasetbd/train/marine animals/Sea Urchins',
#  '/content/datasetbd/train/marine animals/Jelly Fish',
#  '/content/datasetbd/train/marine animals/Turtle_Tortoise',
#  '/content/datasetbd/train/marine animals/Sea Rays',
#  '/content/datasetbd/train/marine animals/Dolphin',
#  '/content/datasetbd/train/marine animals/Corals',
#  '/content/datasetbd/train/marine animals/Penguin',
#  '/content/datasetbd/train/marine animals/Starfish',
#  '/content/datasetbd/train/marine animals/Whale',
#  '/content/datasetbd/train/marine animals/Crabs']

# %%
x = Flatten()(vgg16.output)

# %%
len(folders)
# Out:
# 19

# %% [markdown]
# **4. Adding Output Layer**

# %%
prediction = Dense(len(folders), activation='softmax')(x)

# %% [markdown]
# **5. Creating A Model Object**

# %%
model = Model(inputs=vgg16.input, outputs=prediction)

# %%
model.summary()
# Out:
# Model: "model_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten_3 (Flatten)         (None, 25088)             0
#
#  dense_3 (Dense)             (None, 19)                476691
#
# =================================================================
# Total params: 15,191,379
# Trainable params: 476,691
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %% [markdown]
# **6. Configure The Learning Process**

# %%
model.compile(
  loss='categorical_crossentropy',
  optimizer='adam',
  metrics=['accuracy']
)

# %% [markdown]
# **7. Train The Model**

# %%
r = model.fit(
  xtrain3,
  validation_data=xtest3,
  epochs=20,
  steps_per_epoch=len(xtrain3),
  validation_steps=len(xtest3)
)
# Out:
# Epoch 1/20
# 1175/1175 [==============================] - 222s 188ms/step - loss: 2.1578 - accuracy: 0.5127 - val_loss: 1.6406 - val_accuracy: 0.6306
# Epoch 2/20
# 1175/1175 [==============================] - 220s 187ms/step - loss: 1.5737 - accuracy: 0.6557 - val_loss: 1.6305 - val_accuracy: 0.6985
# Epoch 3/20
# 1175/1175 [==============================] - 223s 190ms/step - loss: 1.3481 - accuracy: 0.7092 - val_loss: 0.9990 - val_accuracy: 0.7590
# Epoch 4/20
# 1175/1175 [==============================] - 224s 191ms/step - loss: 1.1162 - accuracy: 0.7468 - val_loss: 1.0352 - val_accuracy: 0.7751
# Epoch 5/20
# 1175/1175 [==============================] - 227s 193ms/step - loss: 1.0613 - accuracy: 0.7668 - val_loss: 0.8524 - val_accuracy: 0.8109
# Epoch 6/20
# 1175/1175 [==============================] - 219s 186ms/step - loss: 1.0084 - accuracy: 0.7810 - val_loss: 0.7320 - val_accuracy: 0.8255
# Epoch 7/20
# 1175/1175 [==============================] - 220s 188ms/step - loss: 0.8848 - accuracy: 0.8063 - val_loss: 0.4336 - val_accuracy: 0.8806
# Epoch 8/20
# 1175/1175 [==============================] - 221s 188ms/step - loss: 0.7902 - accuracy: 0.8228 - val_loss: 0.5557 - val_accuracy: 0.8683
# Epoch 9/20
# 1175/1175 [==============================] - 222s 189ms/step - loss: 0.7755 - accuracy: 0.8331 - val_loss: 0.6340 - val_accuracy: 0.8534
# Epoch 10/20
# 1175/1175 [==============================] - 221s 188ms/step - loss: 0.7059 - accuracy: 0.8441 - val_loss: 0.5620 - val_accuracy: 0.8655
# Epoch 11/20
# 1175/1175 [==============================] - 222s 189ms/step - loss: 0.6934 - accuracy: 0.8481 - val_loss: 0.4581 - val_accuracy: 0.8904
# Epoch 12/20
# 1175/1175 [==============================] - 221s 188ms/step - loss: 0.6048 - accuracy: 0.8659 - val_loss: 0.6522 - val_accuracy: 0.8812
# Epoch 13/20
# 1175/1175 [==============================] - 218s 186ms/step - loss: 0.5925 - accuracy: 0.8671 - val_loss: 0.3297 - val_accuracy: 0.9168
# Epoch 14/20
# 1175/1175 [==============================] - 216s 184ms/step - loss: 0.5665 - accuracy: 0.8714 - val_loss: 0.3147 - val_accuracy: 0.9189
# Epoch 15/20
# 1175/1175 [==============================] - 216s 184ms/step - loss: 0.5096 - accuracy: 0.8813 - val_loss: 0.2315 - val_accuracy: 0.9394
# Epoch 16/20
# 1175/1175 [==============================] - 217s 184ms/step - loss: 0.5410 - accuracy: 0.8833 - val_loss: 0.5064 - val_accuracy: 0.8930
# Epoch 17/20
# 1175/1175 [==============================] - 216s 184ms/step - loss: 0.4815 - accuracy: 0.8906 - val_loss: 0.3753 - val_accuracy: 0.9112
# Epoch 18/20
# 1175/1175 [==============================] - 215s 183ms/step - loss: 0.4761 - accuracy: 0.8955 - val_loss: 0.2344 - val_accuracy: 0.9392
# Epoch 19/20
# 1175/1175 [==============================] - 214s 182ms/step - loss: 0.4620 - accuracy: 0.9004 - val_loss: 0.3225 - val_accuracy: 0.9222
# Epoch 20/20
# 1175/1175 [==============================] - 214s 182ms/step - loss: 0.4633 - accuracy: 0.9025 - val_loss: 0.5145 - val_accuracy: 0.8951

# %%
from tensorflow.keras.models import load_model

model.save('/content/datasetbd/Model/marine animals.h5')

# %%
from tensorflow.keras.models import load_model
import cv2
from skimage.transform import resize

# %%
model = load_model('/content/datasetbd/Model/marine animals.h5')

# %%
def detect(frame):
  img = cv2.resize(frame,(224,224))
  img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
  
  if(np.max(img)>1):
    img = img/255.0
  img = np.array([img])
  prediction = model.predict(img)
  label = ["Squid","octopus","Whale","Sea Urchins","Turtle_Tortoise","Starfish","Lobster","Eel","Sea Rays","Crabs","Nudibranches","Jelly Fish","Corals","Puffers","Sharks","Dolphin","Seahorse","Penguin","Seal"]
  preds = label[np.argmax(prediction)]
  return preds

# %%
import numpy as np

# %%
data = "/content/datasetbd/train/marine animals/Penguin/.png"
image = cv2.imread(data)
print(detect(image))
# Out:
# 1/1 [==============================] - 0s 16ms/step
# Penguin

# %% [markdown]
# # **For Plants**

# %% [markdown]
# # **MODEL BUILDING**

# %% [markdown]
# **1. Importing The Model Building Libraries**

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Lambda, Dense, Flatten
from tensorflow.keras.models import Model
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.applications.vgg19 import VGG19
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator,load_img
from tensorflow.keras.models import Sequential
import numpy as np
from glob import glob

# %% [markdown]
# **2. Loading The Model**

# %%
IMAGE_SIZE = [224, 224]

train_path = '/content/datasetbd/train/plants'
valid_path = '/content/datasetbd/test/plants'

# %%
vgg16 = VGG16(input_shape=IMAGE_SIZE + [3], weights='imagenet', include_top=False)

# %% [markdown]
# **3. Adding Flatten Layer**

# %%
for layer in vgg16.layers:
    layer.trainable = False

# %%
folders = glob('/content/datasetbd/train/plants/*')

# %%
folders
# Out:
# ['/content/datasetbd/train/plants/Daisy Fleabane',
#  '/content/datasetbd/train/plants/joe_pye_weed',
#  '/content/datasetbd/train/plants/agapanthus',
#  '/content/datasetbd/train/plants/crocus_blue',
#  '/content/datasetbd/train/plants/wild_bee_balm_flowers',
#  '/content/datasetbd/train/plants/baby_breath_flower',
#  '/content/datasetbd/train/plants/crimson_clover',
#  '/content/datasetbd/train/plants/zinnia_flower_red',
#  '/content/datasetbd/train/plants/blue_chicory',
#  '/content/datasetbd/train/plants/Wild Leek',
#  '/content/datasetbd/train/plants/Madagascar_Periwinkle',
#  '/content/datasetbd/train/plants/mallow_flower',
#  '/content/datasetbd/train/plants/almond',
#  '/content/datasetbd/train/plants/daisy',
#  '/content/datasetbd/train/plants/Banana',
#  '/content/datasetbd/train/plants/aster',
#  '/content/datasetbd/train/plants/aloe_vera',
#  '/content/datasetbd/train/plants/black_rose_flower',
#  '/content/datasetbd/train/plants/aeonium',
#  '/content/datasetbd/train/plants/yellow_sow_thistle',
#  '/content/datasetbd/train/plants/Wild Grape Vine',
#  '/content/datasetbd/train/plants/yucca',
#  '/content/datasetbd/train/plants/Daffodil_flower',
#  '/content/datasetbd/train/plants/datura_flower',
#  '/content/datasetbd/train/plants/coronation_gold',
#  '/content/datasetbd/train/plants/Crabs',
#  '/content/datasetbd/train/plants/dandelion']

# %%
x = Flatten()(vgg16.output)

# %%
len(folders)
# Out:
# 27

# %% [markdown]
# **4. Adding Output Layer**

# %%
prediction = Dense(len(folders), activation='softmax')(x)

# %% [markdown]
# **5. Creating A Model Object**

# %%
model = Model(inputs=vgg16.input, outputs=prediction)

# %%
model.summary()
# Out:
# Model: "model_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten_4 (Flatten)         (None, 25088)             0
#
#  dense_4 (Dense)             (None, 27)                677403
#
# =================================================================
# Total params: 15,392,091
# Trainable params: 677,403
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %% [markdown]
# **6. Configure The Learning Process**

# %%
model.compile(
  loss='categorical_crossentropy',
  optimizer='adam',
  metrics=['accuracy']
)

# %% [markdown]
# **7. Train The Model**

# %%
r = model.fit(
  xtrain4,
  validation_data=xtest4,
  epochs=10,
  steps_per_epoch=len(xtrain4),
  validation_steps=len(xtest4)
)
# Out:
# Epoch 1/10
# 369/369 [==============================] - 73s 197ms/step - loss: 2.3727 - accuracy: 0.4653 - val_loss: 0.9468 - val_accuracy: 0.7373
# Epoch 2/10
# 369/369 [==============================] - 71s 193ms/step - loss: 1.2295 - accuracy: 0.7191 - val_loss: 0.7407 - val_accuracy: 0.7972
# Epoch 3/10
# 369/369 [==============================] - 72s 195ms/step - loss: 0.9279 - accuracy: 0.7847 - val_loss: 0.5616 - val_accuracy: 0.8520
# Epoch 4/10
# 369/369 [==============================] - 71s 193ms/step - loss: 0.8289 - accuracy: 0.8175 - val_loss: 0.7705 - val_accuracy: 0.8745
# Epoch 5/10
# 369/369 [==============================] - 71s 193ms/step - loss: 0.6094 - accuracy: 0.8666 - val_loss: 0.3795 - val_accuracy: 0.9021
# Epoch 6/10
# 369/369 [==============================] - 71s 193ms/step - loss: 0.5877 - accuracy: 0.8774 - val_loss: 0.6357 - val_accuracy: 0.8574
# Epoch 7/10
# 369/369 [==============================] - 72s 194ms/step - loss: 0.5976 - accuracy: 0.8793 - val_loss: 0.5187 - val_accuracy: 0.8858
# Epoch 8/10
# 369/369 [==============================] - 71s 194ms/step - loss: 0.5464 - accuracy: 0.8823 - val_loss: 0.2997 - val_accuracy: 0.9328
# Epoch 9/10
# 369/369 [==============================] - 71s 193ms/step - loss: 0.5973 - accuracy: 0.8967 - val_loss: 0.7207 - val_accuracy: 0.8655
# Epoch 10/10
# 369/369 [==============================] - 72s 194ms/step - loss: 0.6799 - accuracy: 0.8796 - val_loss: 0.2878 - val_accuracy: 0.9403

# %%
from tensorflow.keras.models import load_model

model.save('/content/datasetbd/Model/plants.h5')

# %%
from tensorflow.keras.models import load_model
import cv2
from skimage.transform import resize

# %%
model = load_model('/content/datasetbd/Model/plants.h5')

# %%
def detect(frame):
  img = cv2.resize(frame,(224,224))
  img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
  
  if(np.max(img)>1):
    img = img/255.0
  img = np.array([img])
  prediction = model.predict(img)
  label = ["aeonium","agapanthus","almond","aloe_vera","aster","baby_breath_flower","Banana","black_rose_flower","blue_chicory","coronation_gold","Crabs","crimson_clover","crocus_blue","Daffodil_flower","daisy","Daisy fleabane","dandelion","datura_flower","joe_pye_weed","Madagascar_Periwinkle","mallow_flower","Wild Grape vine","Wild Leek","wild_bee_balm_flowers","yellow_sow_thistle","yucca","zinna_flower_red"]
  preds = label[np.argmax(prediction)]
  return preds

# %%
import numpy as np

# %%
data = "/content/datasetbd/train/plants/yellow_sow_thistle/yellow_sow_thistle_101.jpg"
image = cv2.imread(data)
print(detect(image))
# Out:
# 1/1 [==============================] - 0s 16ms/step
# yellow_sow_thistle
